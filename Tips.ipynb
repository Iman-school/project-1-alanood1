# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

data = pd.read_csv('tips.csv')
data.head(30)
# Out:
#     total_bill   tip     sex smoker  day    time  size
# 0        16.99  1.01  Female     No  Sun  Dinner     2
# 1        10.34  1.66    Male     No  Sun  Dinner     3
# 2        21.01  3.50    Male     No  Sun  Dinner     3
# 3        23.68  3.31    Male     No  Sun  Dinner     2
# 4        24.59  3.61  Female     No  Sun  Dinner     4
# 5        25.29  4.71    Male     No  Sun  Dinner     4
# 6         8.77  2.00    Male     No  Sun  Dinner     2
# 7        26.88  3.12    Male     No  Sun  Dinner     4
# 8        15.04  1.96    Male     No  Sun  Dinner     2
# 9        14.78  3.23    Male     No  Sun  Dinner     2
# 10       10.27  1.71    Male     No  Sun  Dinner     2
# 11       35.26  5.00  Female     No  Sun  Dinner     4
# 12       15.42  1.57    Male     No  Sun  Dinner     2
# 13       18.43  3.00    Male     No  Sun  Dinner     4
# 14       14.83  3.02  Female     No  Sun  Dinner     2
# 15       21.58  3.92    Male     No  Sun  Dinner     2
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    object
#  3   smoker      244 non-null    object
#  4   day         244 non-null    object
#  5   time        244 non-null    object
#  6   size        244 non-null    int64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 13.5+ KB

# %%
#we zero missing values

# %%
import seaborn as sns


tips = sns.catplot(
    data=df, kind="bar",
    x="sex", y="tip", hue="time"
)

# %%
import seaborn as sns


tips = sns.catplot(
    data=df, kind="bar",
    x="sex", y="total_bill", hue="day"
)

# %%
import seaborn as sns


tips = sns.catplot(
    data=df, kind="bar",
    x="day", y="tip"
)

# %%
sns.scatterplot(data=df, x="total_bill", y="tip")
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(x="smoker", y="total_bill",
                 
                data=df)
# Out:
# <AxesSubplot:xlabel='smoker', ylabel='total_bill'>

# %%
import seaborn as sns


tips = sns.catplot(
    data=df, kind="bar",
    x="total_bill", y="smoker"
)

# %%
g = sns.FacetGrid(df, row="smoker", col="time", margin_titles=True)
g.map(sns.regplot, "size", "total_bill", color=".1", fit_reg=False, x_jitter=.1)

# %%
pal = dict(Lunch="seagreen", Dinner=".7")
g = sns.FacetGrid(df, hue="time", palette=pal, height=5)
g.map(sns.scatterplot, "total_bill", "a", s=100, alpha=.5)
g.add_legend()

# %%
g = sns.FacetGrid(df, col="sex", height=4, aspect=.5)
g.map(sns.barplot, "smoker", "total_bill", order=["No", "Yes"])

# %%
g = sns.FacetGrid(df, col="sex", height=4, aspect=.5)
g.map(sns.barplot, "size", "total_bill", order=[1,2,3,4,5,6])

# %%
with sns.axes_style("white"):
    g = sns.FacetGrid(df, row="sex", col="smoker", margin_titles=True, height=2.5)
g.map(sns.scatterplot, "total_bill", "tip", color="#444888")
g.set_axis_labels("Total bill (US Dollars)", "Tip")
